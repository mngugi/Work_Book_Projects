# %% [markdown]
# <a href="https://colab.research.google.com/github/mngugi/Work_Book_Projects/blob/main/matplotReview_Colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
plt.plot([2,11,15,40], [4,8,15,22], color = 'r')
plt.show()

# %%
fig = plt.figure()

names = ['Joe','John','Jack']
values = [70,89,65]
rank = [2,1,3]


ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax.bar(names, values)
ax2.bar(names, rank)

plt.show()
