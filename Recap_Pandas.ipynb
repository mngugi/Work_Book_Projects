# %% [markdown]
# <a href="https://colab.research.google.com/github/mngugi/Work_Book_Projects/blob/main/Recap_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas package

import pandas as pd

DataFrame = pd.DataFrame ( {
    "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],

}



)

DataFrame
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
DataFrame ['Age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64
