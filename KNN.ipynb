# %% [markdown]
# <a href="https://colab.research.google.com/github/mngugi/Work_Book_Projects/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [65,98,75,45,85,71,65,74]
y = [56,89,57,54,58,71,65,87]


Classes = [0,1,0,1,1,0,0,1]



plt.scatter(x,y, c=Classes)
plt.show()
